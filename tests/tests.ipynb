# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les fichiers JSON

def test(file1 , file2) :

    data1 = pd.read_json(file1)
    data2 = pd.read_json(file2)

    # Extraire les dates et les prix
    data1_sorted = data1.sort_values(by="date")
    data2_sorted = data2.sort_values(by="date")

    # data1_sorted['date'] = pd.to_datetime(data1_sorted['date'])
    # data2_sorted['date'] = pd.to_datetime(data2_sorted['date'])

    # Vérifier l'intersection des dates communes
    common_dates = pd.merge(data1_sorted[['date', 'price']], data2_sorted[['date', 'price']], on='date', suffixes=('_file1', '_file2'))

    # Tracer les données
    plt.figure(figsize=(12, 6))
    plt.plot(common_dates['date'], common_dates['price_file1'], label='Fichier 1 - Price', marker='o')
    plt.plot(common_dates['date'], common_dates['price_file2'], label='Fichier 2 - Price', marker='s')

    # Personnalisation du graphique
    plt.title('Comparaison des prix entre deux fichiers JSON')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # Afficher le graphique
    plt.tight_layout()
    plt.show()


def test_hedging(file1 , file2) :

    data1 = pd.read_json(file1)
    data2 = pd.read_json(file2)

    # Extraire les dates et les prix
    data1_sorted = data1.sort_values(by="date")
    data2_sorted = data2.sort_values(by="date")


    # Vérifier l'intersection des dates communes
    common_dates = pd.merge(data1_sorted[['date', 'value']], data2_sorted[['date', 'value']], on='date', suffixes=('_file1', '_file2'))

    # Tracer les données
    plt.figure(figsize=(12, 6))
    plt.plot(common_dates['date'], common_dates['value_file1'], label='Fichier 1 - Value', marker='o')
    plt.plot(common_dates['date'], common_dates['value_file2'], label='Fichier 2 - Value', marker='s')

    # Personnalisation du graphique
    plt.title('Comparaison des valeurs de portefeuille entre deux fichiers JSON')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # Afficher le graphique
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Test : Call Currency

# %%
test("./call_currency_res.json" , "../data/call_currency/call_currency_portfolio.json")
test_hedging("./call_currency_res.json" , "../data/call_currency/call_currency_portfolio.json")

# %% [markdown]
# ### Test : Call Qunato

# %%
test('./call_quanto_res.json' , '../data/call_quanto/call_quanto_portfolio.json')
test_hedging('./call_quanto_res.json' , '../data/call_quanto/call_quanto_portfolio.json')

# %% [markdown]
# ### Test : Foreign Asian

# %%
test('./foreign_asian_res.json' , '../data/foreign_asian/foreign_asian_portfolio.json')
test_hedging('./foreign_asian_res.json' , '../data/foreign_asian/foreign_asian_portfolio.json')

# %% [markdown]
# ### Test : Foreign Perf Basket

# %%
test('./foreign_perf_basket_res.json' , '../data/foreign_perf_basket/foreign_perf_basket_portfolio.json')
test_hedging('./foreign_perf_basket_res.json' , '../data/foreign_perf_basket/foreign_perf_basket_portfolio.json')

# %% [markdown]
# ### Test : Quanto Exchange

# %%
test('./quanto_exchange_res.json' , '../data/quanto_exchange/quanto_exchange_portfolio.json')
test_hedging('./quanto_exchange_res.json' , '../data/quanto_exchange/quanto_exchange_portfolio.json')
